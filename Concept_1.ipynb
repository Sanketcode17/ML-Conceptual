# %%
#Import Python Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Que. no.7**

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-60cbc0bd-2152-433f-83d7-9fcc1b5742f5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-60cbc0bd-2152-433f-83d7-9fcc1b5742f5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data=pd.read_csv('Q7 (1).csv')

# %%
data.head()
# Out:
#           Unnamed: 0  Points  Score  Weigh
# 0          Mazda RX4    3.90  2.620  16.46
# 1      Mazda RX4 Wag    3.90  2.875  17.02
# 2         Datsun 710    3.85  2.320  18.61
# 3     Hornet 4 Drive    3.08  3.215  19.44
# 4  Hornet Sportabout    3.15  3.440  17.02

# %%
data.describe()
# Out:
#           Points      Score      Weigh
# count  32.000000  32.000000  32.000000
# mean    3.596563   3.217250  17.848750
# std     0.534679   0.978457   1.786943
# min     2.760000   1.513000  14.500000
# 25%     3.080000   2.581250  16.892500
# 50%     3.695000   3.325000  17.710000
# 75%     3.920000   3.610000  18.900000
# max     4.930000   5.424000  22.900000

# %% [markdown]
# **Que. no.9(a)**

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6b44eac3-8e96-487f-aed7-200e8759a25a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6b44eac3-8e96-487f-aed7-200e8759a25a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data_1=pd.read_csv('Q9_a (1).csv')

# %%
data_1.head()
# Out:
#    Index  speed  dist
# 0      1      4     2
# 1      2      4    10
# 2      3      7     4
# 3      4      7    22
# 4      5      8    16

# %%
from scipy.stats import skew
from scipy.stats import kurtosis
print(skew(data_1.speed))
print(skew(data_1.dist))
print(kurtosis(data_1.speed,fisher=False))
print(kurtosis(data_1.dist,fisher=False))
# Out:
# -0.11395477012828319
# 0.7824835173114966
# 2.422852576056263
# 3.248018657170518

# %%
import matplotlib.pyplot as plt
import seaborn as sn
# %matplotlib inline
sn.distplot(data_1["speed"])
# Out:
# <ipython-input-12-7f00c0a80ca7>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(data_1["speed"])
# <Axes: xlabel='speed', ylabel='Density'>

# %%
sn.distplot(data_1["dist"])
# Out:
# <ipython-input-13-ea5912bed11f>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(data_1["dist"])
# <Axes: xlabel='dist', ylabel='Density'>

# %% [markdown]
# **Que. 9(b)**

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-3fc77840-67c7-48c8-9e39-ae5c227636d8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3fc77840-67c7-48c8-9e39-ae5c227636d8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data_2=pd.read_csv('Q9_b (1).csv')

# %%
data_2.head()
# Out:
#    Unnamed: 0          SP         WT
# 0           1  104.185353  28.762059
# 1           2  105.461264  30.466833
# 2           3  105.461264  30.193597
# 3           4  113.461264  30.632114
# 4           5  104.461264  29.889149

# %%
from scipy.stats import skew
from scipy.stats import kurtosis
print(skew(data_2.SP))
print(skew(data_2.WT))
print(kurtosis(data_2.SP,fisher=False))
print(kurtosis(data_2.WT,fisher=False))
# Out:
# 1.5814536794423764
# -0.6033099322115126
# 5.723521486526924
# 3.819465879226685

# %%
import matplotlib.pyplot as plt
import seaborn as sn
# %matplotlib inline
sn.distplot(data_2["SP"])
# Out:
# <ipython-input-18-3738d3001bcc>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(data_2["SP"])
# <Axes: xlabel='SP', ylabel='Density'>

# %%
sn.distplot(data_2["WT"])
# Out:
# <ipython-input-19-a41c749e7300>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(data_2["WT"])
# <Axes: xlabel='WT', ylabel='Density'>

# %% [markdown]
# **Que. no.11**

# %%
from scipy import stats
stats.t.interval(0.94,1999,200,30/2000**0.5)
# Out:
# (198.7376089443071, 201.2623910556929)

# %%
stats.t.interval(0.96,1999,200,30/2000**0.5)
# Out:
# (198.6214037429732, 201.3785962570268)

# %%
stats.t.interval(0.98,1999,200,30/2000**0.5)
# Out:
# (198.4381860483216, 201.5618139516784)

# %% [markdown]
# **Que. no. 20**

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-16ac7b9c-5670-4fa2-a52f-ac61f4192b52" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-16ac7b9c-5670-4fa2-a52f-ac61f4192b52">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data_3=pd.read_csv('Cars (1).csv')

# %%
data_3.head()
# Out:
#    HP        MPG  VOL          SP         WT
# 0  49  53.700681   89  104.185353  28.762059
# 1  55  50.013401   92  105.461264  30.466833
# 2  55  50.013401   92  105.461264  30.193597
# 3  70  45.696322   92  113.461264  30.632114
# 4  53  50.504232   92  104.461264  29.889149

# %%
data_3['MPG'].mean()
# Out:
# 34.42207572802469

# %%
# for P(MPG>38)
from scipy import stats
1-stats.norm.cdf(38,data_3["MPG"].mean(),data_3["MPG"].std())
# Out:
# 0.34759392515827137

# %%
# for P(MPG<40)
stats.norm.cdf(40,data_3["MPG"].mean(),data_3["MPG"].std())
# Out:
# 0.7293498762151609

# %%
# for P(20<MPG<50)
stats.norm.cdf(50,data_3["MPG"].mean(),data_3["MPG"].std()) - stats.norm.cdf(20,data_3["MPG"].mean(),data_3["MPG"].std())
# Out:
# 0.8988689169682047

# %% [markdown]
# **Que. no.21(a)**

# %%
sn.distplot(data_3["MPG"])
# Out:
# <ipython-input-32-6cbe033c26c3>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(data_3["MPG"])
# <Axes: xlabel='MPG', ylabel='Density'>

# %%
from scipy.stats import skew
from scipy.stats import kurtosis
print(skew(data_3.MPG))
print(kurtosis(data_3.MPG,fisher=False))
# Out:
# -0.17463433818755686
# 2.3522616039754074

# %% [markdown]
# **Que. no.21(b)**

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-a0a3f13f-a3ff-434a-b40a-60172d7332b0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a0a3f13f-a3ff-434a-b40a-60172d7332b0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data_4=pd.read_csv('wc-at (1).csv')

# %%
data_4.head()
# Out:
#    Waist     AT
# 0  74.75  25.72
# 1  72.60  25.89
# 2  81.80  42.60
# 3  83.95  42.80
# 4  74.65  29.84

# %%
sn.distplot(data_4.Waist)
# Out:
# <ipython-input-37-1eb16a3840f4>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(data_4.Waist)
# <Axes: xlabel='Waist', ylabel='Density'>

# %%
sn.distplot(data_4.AT)
# Out:
# <ipython-input-38-072c48562f38>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(data_4.AT)
# <Axes: xlabel='AT', ylabel='Density'>

# %%
from scipy.stats import skew
from scipy.stats import kurtosis
print(skew(data_4.Waist))
print(kurtosis(data_4.Waist))
print(skew(data_4.AT))
print(kurtosis(data_4.AT))
# Out:
# 0.1322041763592883
# -1.1072764806858817
# 0.5767896975987847
# -0.3271884938021854

# %% [markdown]
# **Que. no.22**

# %%
stats.norm.interval(0.60)
# Out:
# (-0.8416212335729142, 0.8416212335729143)

# %%
stats.norm.interval(0.90)
# Out:
# (-1.6448536269514729, 1.6448536269514722)

# %%
stats.norm.interval(0.94)
# Out:
# (-1.8807936081512509, 1.8807936081512509)

# %% [markdown]
# **Que. no.23**

# %%
stats.t.interval(0.95,24)
# Out:
# (-2.0638985616280205, 2.0638985616280205)

# %%
stats.t.interval(0.96,24)
# Out:
# (-2.1715446760080677, 2.1715446760080677)

# %%
stats.t.interval(0.99,24)
# Out:
# (-2.796939504772804, 2.796939504772804)

# %% [markdown]
# **Que.no.24**

# %%
stats.t.cdf(260,df=17,loc=270,scale=90/18**0.5)
# Out:
# 0.32167253567098364
