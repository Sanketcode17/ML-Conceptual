# %% [markdown]
# # **Build a simple linear regression model by performing EDA and do necessary transformations and select the best model using R or Python.**

# %% [markdown]
# **1)Delivery_time -> Predict delivery time using sorting time **

# %%
import pandas as pd
import numpy as np
import sklearn
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import statsmodels.formula.api as smf
from sklearn.metrics import r2_score

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-26058061-daf7-41b6-a926-96d578abac97" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-26058061-daf7-41b6-a926-96d578abac97">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df_dt=pd.read_csv("delivery_time.csv")
df_dt
# Out:
#     Delivery Time  Sorting Time
# 0           21.00            10
# 1           13.50             4
# 2           19.75             6
# 3           24.00             9
# 4           29.00            10
# 5           15.35             6
# 6           19.00             7
# 7            9.50             3
# 8           17.90            10
# 9           18.75             9
# 10          19.83             8
# 11          10.75             4
# 12          16.68             7
# 13          11.50             3
# 14          12.03             3
# 15          14.88             4
# 16          13.75             6
# 17          18.11             7
# 18           8.00             2
# 19          17.83             7
# 20          21.50             5

# %%
dfdt=df_dt.rename(columns={'Delivery Time':'DT','Sorting Time':'ST'},inplace=False)
dfdt
# Out:
#        DT  ST
# 0   21.00  10
# 1   13.50   4
# 2   19.75   6
# 3   24.00   9
# 4   29.00  10
# 5   15.35   6
# 6   19.00   7
# 7    9.50   3
# 8   17.90  10
# 9   18.75   9
# 10  19.83   8
# 11  10.75   4
# 12  16.68   7
# 13  11.50   3
# 14  12.03   3
# 15  14.88   4
# 16  13.75   6
# 17  18.11   7
# 18   8.00   2
# 19  17.83   7
# 20  21.50   5

# %%
plt.scatter(dfdt.ST,dfdt.DT)

# %%
dfdt.corr()
# Out:
#           DT        ST
# DT  1.000000  0.825997
# ST  0.825997  1.000000

# %%
dtmodel1 = smf.ols("DT~ST",data=dfdt).fit()

# %%
dtmodel1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                     DT   R-squared:                       0.682
# Model:                            OLS   Adj. R-squared:                  0.666
# Method:                 Least Squares   F-statistic:                     40.80
# Date:                Sun, 22 Oct 2023   Prob (F-statistic):           3.98e-06
# Time:                        04:24:36   Log-Likelihood:                -51.357
# No. Observations:                  21   AIC:                             106.7
# Df Residuals:                      19   BIC:                             108.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      6.5827      1.722      3.823      0.001       2.979      10.186
# ...

# %%
Yhat1=dtmodel1.predict(dfdt["ST"])
Yhat1
# Out:
# 0     23.072933
# 1     13.178814
# 2     16.476853
# 3     21.423913
# 4     23.072933
# 5     16.476853
# 6     18.125873
# 7     11.529794
# 8     23.072933
# 9     21.423913
# 10    19.774893
# 11    13.178814
# 12    18.125873
# 13    11.529794
# 14    11.529794
# 15    13.178814
# 16    16.476853
# 17    18.125873
# 18     9.880774
# 19    18.125873
# 20    14.827833
# dtype: float64

# %%
plt.scatter(dfdt.ST,dfdt.DT)
plt.plot(dfdt.ST,Yhat1,color="orange")
plt.xlabel("Sorting time")
plt.ylabel("Delivery time")
# Out:
# Text(0, 0.5, 'Delivery time')

# %%
dtmodel2 = smf.ols("np.log(DT)~np.log(ST)",data=dfdt).fit()
dtmodel2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             np.log(DT)   R-squared:                       0.772
# Model:                            OLS   Adj. R-squared:                  0.760
# Method:                 Least Squares   F-statistic:                     64.39
# Date:                Sun, 22 Oct 2023   Prob (F-statistic):           1.60e-07
# Time:                        04:25:39   Log-Likelihood:                 10.291
# No. Observations:                  21   AIC:                            -16.58
# Df Residuals:                      19   BIC:                            -14.49
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.7420      0.133     13.086      0.000       1.463       2.021
# ...

# %%
Yhat2 = np.exp(dtmodel2.predict(dfdt[["ST","LogST"]]))
Yhat2
# Out:
# 0     22.597360
# 1     13.070123
# 2     16.653216
# 3     21.218593
# 4     22.597360
# 5     16.653216
# 6     18.259981
# 7     11.005911
# 8     22.597360
# 9     21.218593
# 10    19.776608
# 11    13.070123
# 12    18.259981
# 13    11.005911
# 14    11.005911
# 15    13.070123
# 16    16.653216
# 17    18.259981
# 18     8.637887
# 19    18.259981
# 20    14.934324
# dtype: float64

# %%
dfdt["LogST"]= np.log(dfdt.ST)
dfdt
# Out:
#        DT  ST     LogST
# 0   21.00  10  2.302585
# 1   13.50   4  1.386294
# 2   19.75   6  1.791759
# 3   24.00   9  2.197225
# 4   29.00  10  2.302585
# 5   15.35   6  1.791759
# 6   19.00   7  1.945910
# 7    9.50   3  1.098612
# 8   17.90  10  2.302585
# 9   18.75   9  2.197225
# 10  19.83   8  2.079442
# 11  10.75   4  1.386294
# 12  16.68   7  1.945910
# 13  11.50   3  1.098612
# 14  12.03   3  1.098612
# 15  14.88   4  1.386294
# 16  13.75   6  1.791759
# 17  18.11   7  1.945910
# 18   8.00   2  0.693147
# 19  17.83   7  1.945910
# 20  21.50   5  1.609438

# %%
plt.scatter(dfdt.ST,dfdt.DT)
plt.plot(dfdt.ST,Yhat2,color="orange")
plt.xlabel("Sorting time")
plt.ylabel("Delivery time")
# Out:
# Text(0, 0.5, 'Delivery time')

# %%
#Yhat2 is Predicted delivery time using sorting time and using model 2
Yhat2=np.exp(dtmodel2.predict(dfdt[["ST","LogST"]]))
Yhat2
# Out:
# 0     22.597360
# 1     13.070123
# 2     16.653216
# 3     21.218593
# 4     22.597360
# 5     16.653216
# 6     18.259981
# 7     11.005911
# 8     22.597360
# 9     21.218593
# 10    19.776608
# 11    13.070123
# 12    18.259981
# 13    11.005911
# 14    11.005911
# 15    13.070123
# 16    16.653216
# 17    18.259981
# 18     8.637887
# 19    18.259981
# 20    14.934324
# dtype: float64

# %% [markdown]
# **2)Build a prediction model for Salary_hike**

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-db987953-6a99-4cba-88e4-9681c04fd145" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-db987953-6a99-4cba-88e4-9681c04fd145">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df_sh = pd.read_csv("Salary_Data.csv")
df_sh
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
plt.scatter(df_sh.YearsExperience,df_sh.Salary)

# %%
df_sh.corr()
# Out:
#                  YearsExperience    Salary
# YearsExperience         1.000000  0.978242
# Salary                  0.978242  1.000000

# %%
shmodel1= smf.ols('Salary~YearsExperience',data=df_sh).fit()
shmodel1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Salary   R-squared:                       0.957
# Model:                            OLS   Adj. R-squared:                  0.955
# Method:                 Least Squares   F-statistic:                     622.5
# Date:                Sun, 22 Oct 2023   Prob (F-statistic):           1.14e-20
# Time:                        04:34:50   Log-Likelihood:                -301.44
# No. Observations:                  30   AIC:                             606.9
# Df Residuals:                      28   BIC:                             609.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
#As rsquare is 0.957 so shmodel2 is good model
Yhatsh1= shmodel1.predict(df_sh.YearsExperience)
Yhatsh1
# Out:
# 0      36187.158752
# 1      38077.151217
# 2      39967.143681
# 3      44692.124842
# 4      46582.117306
# 5      53197.090931
# 6      54142.087163
# 7      56032.079627
# 8      56032.079627
# 9      60757.060788
# 10     62647.053252
# 11     63592.049484
# 12     63592.049484
# 13     64537.045717
# 14     68317.030645
# 15     72097.015574
# 16     73987.008038
# 17     75877.000502
# 18     81546.977895
# 19     82491.974127
# 20     90051.943985
# 21     92886.932681
# 22    100446.902538
# 23    103281.891235
# 24    108006.872395
# 25    110841.861092
# 26    115566.842252
# 27    116511.838485
# 28    123126.812110
# 29    125016.804574
# dtype: float64

# %%
plt.scatter(df_sh.YearsExperience,df_sh.Salary)
plt.plot(df_sh.YearsExperience,Yhatsh1,color="red")
plt.xlabel("Years of Experience")
plt.ylabel("Salary Hike")
# Out:
# Text(0, 0.5, 'Salary Hike')

# %%
#So the salary hike is predicted with help of Yhatsh1 and shmodel1
